# %%
import pandas as pd
import numpy as np

south_sudan_funding = pd.read_csv('/Workspace/Users/maic@ufl.edu/fts_requirements_funding_cluster_ssd.csv')

# %%
# # table is Unity Catalog, so need to open like this
# south_sudan_funding_requirements = spark.table('workspace.default.requirements_funding_cluster_south_sudan')
# display(south_sudan_funding_requirements.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>countryCode</th><th>id</th><th>name</th><th>code</th><th>startDate</th><th>endDate</th><th>year</th><th>clusterCode</th><th>cluster</th><th>requirements</th><th>funding</th><th>percentFunded</th></tr></thead><tbody><tr><td>SSD</td><td>1512</td><td>South Sudan Humanitarian Needs and Response Plan 2026</td><td>HSSD26</td><td>1/1/2026</td><td>2026-12-31</td><td>2026</td><td>8617</td><td>Camp Coordination  and Camp  Management</td><td>16927678</td><td>0</td><td>0</td></tr><tr><td>SSD</td><td>1512</td><td>South Sudan Humanitarian Needs and Response Plan 2026</td><td>HSSD26</td><td>1/1/2026</td><td>2026-12-31</td><td>2026</td><td>8709</td><td>Coordination,  Thematic and  System Support</td><td>33230246</td><td>12509059</td><td>38</td></tr><tr><td>SSD</td><td>1512</td><td>South Sudan Humanitarian Needs and Response Plan 2026</td><td>HSSD26</td><td>1/1/2026</td><td>2026-12-31</td><td>2026</td><td>8701</td><td>Education</td><td>47731938</td><td>16150511</td><td>34</td></tr><tr><td>SSD</td><td>1512</td><td>South Sudan Humanitarian Needs and Response Plan 2026</td><td>HSSD26</td><td>1/1/2026</td><td>2026-12-31</td><td>2026</td><td>8702</td><td>Food Security</td><td>410560173</td><td>22226220</td><td>5</td></tr><tr><td>SSD</td><td>1512</td><td>South Sudan Humanitarian Needs and Response Plan 2026</td><td>HSSD26</td><td>1/1/2026</td><td>2026-12-31</td><td>2026</td><td>8703</td><td>Health</td><td>113653248</td><td>9779137</td><td>9</td></tr></tbody></table></div>
