# %%
import pandas as pd
import numpy as np

# %%
# %run "/Workspace/Users/elizabethnguyen@ufl.edu/needs_requirements_notebook"
# Out:
# /home/spark-9421417e-8a2b-4429-a3be-e9/.ipykernel/2611/command-6230745727157871-1594228415:1: DtypeWarning: Columns (1,2,5,6,10,11,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   needs = pd.read_csv('/Workspace/Users/elizabethnguyen@ufl.edu/hpc_hno_2025.csv')
#        Country ISO3 Admin 1 PCode Admin 1 Name  ... Reached Info Cluster Full
# 47              AFG           NaN          NaN  ...     NaN  NaN  All Sectors
# 514             AFG          AF01        Kabul  ...     NaN  NaN  All Sectors
# 961             AFG           NaN          NaN  ...     NaN  NaN  All Sectors
# 1388            AFG           NaN          NaN  ...     NaN  NaN  All Sectors
# 1633            AFG           NaN          NaN  ...     NaN  NaN  All Sectors
# ...             ...           ...          ...  ...     ...  ...          ...
# 317954          YEM           NaN          NaN  ...     NaN  NaN  All Sectors
# ...

# %%
# %run "/Workspace/Users/elizabethnguyen@ufl.edu/Adding_Country_Names"
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  ...      funding percentFunded
# 0               0             0  ...    7101118.0          21.0
# 1               1             1  ...   80113551.0          86.0
# 2               2             2  ...   28287010.0          16.0
# 3               3             3  ...  202583088.0          19.0
# 4               4             4  ...  127002611.0          45.0
# ..            ...           ...  ...          ...           ...
# 429           429           429  ...    1545466.0          23.0
# 430           430           430  ...     477106.0         173.0
# 431           431           431  ...    1224531.0          12.0
# 432           432           432  ...      37778.0           4.0
# 433           433           433  ...     287425.0           2.0
#
# [434 rows x 16 columns]

# %%
allocation_df = pd.read_csv("/Workspace/Users/elizabethnguyen@ufl.edu/cbpf_allocation_by_org_type.csv")
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  ...      funding percentFunded
# 0               0             0  ...    7101118.0          21.0
# 1               1             1  ...   80113551.0          86.0
# 2               2             2  ...   28287010.0          16.0
# 3               3             3  ...  202583088.0          19.0
# 4               4             4  ...  127002611.0          45.0
# ..            ...           ...  ...          ...           ...
# 429           429           429  ...    1545466.0          23.0
# 430           430           430  ...     477106.0         173.0
# 431           431           431  ...    1224531.0          12.0
# 432           432           432  ...      37778.0           4.0
# 433           433           433  ...     287425.0           2.0
#
# [434 rows x 16 columns]
#      Unnamed: 0.2  Unnamed: 0.1  ...      funding  percentFunded
# 0               0             0  ...    7101118.0           21.0
# ...

# %%
#Turn the columns into floats to prepare for operations
total_needs_for_all_cluster["In Need"] = total_needs_for_all_cluster["In Need"].astype(float)
allocation_df["Total Allocation"] = allocation_df["Total Allocation"].astype(float)

#Group the two dataframes by country
national_needs = total_needs_for_all_cluster.groupby("Country ISO3").head(1)
national_allocations = allocation_df.groupby("Country Code").head(1)

#Merge the two dataframes by country
final_total_df = national_needs.merge(
    national_allocations,
    left_on="Country ISO3",
    right_on="Country Code",
    how="inner"
)

#Divide Total Allocation by In Need
final_total_df["Beneficiaries-to-Budget Ratio"] = final_total_df["Total Allocation"] / final_total_df["In Need"]

#Make the dataframe only have needed columns
final_total_df = final_total_df[["Country ISO3", "Population", "In Need", "Total Allocation", "Beneficiaries-to-Budget Ratio"]]

final_total_df
# Out:
# /home/spark-9421417e-8a2b-4429-a3be-e9/.ipykernel/2611/command-6230745727158110-3822358178:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_needs_for_all_cluster["In Need"] = total_needs_for_all_cluster["In Need"].astype(float)
#    Country ISO3  Population  ...  Total Allocation  Beneficiaries-to-Budget Ratio
# 0           AFG  46024352.0  ...      7.343874e+07                       3.208652
# 1           BFA  23449865.0  ...      8.997558e+06                       1.521108
# 2           COL  53110609.0  ...      0.000000e+00                       0.000000
# 3           HTI  11899555.0  ...      2.162359e+06                       0.361209
# 4           MLI  23134540.0  ...      8.012337e+06                       1.245789
# ...
